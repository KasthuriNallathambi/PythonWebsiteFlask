# %%
import pandas as pd

# %% [markdown]
# Load the dataframe

# %%
df = pd.read_csv('wines.csv')

# %%
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %% [markdown]
# How many wines have been given a rating of 100 points?

# %%
#df.loc[df['points']==100]['title']
df[df['points']==100]['title']
# Out:
# 345       Chambers Rosewood Vineyards NV Rare Muscat (Ru...
# 7335      Avignonesi 1995 Occhio di Pernice  (Vin Santo ...
# 36528                           Krug 2002 Brut  (Champagne)
# 39286     Tenuta dell'Ornellaia 2007 Masseto Merlot (Tos...
# 42197         Casa Ferreirinha 2008 Barca-Velha Red (Douro)
# 45781     Biondi Santi 2010 Riserva  (Brunello di Montal...
# 45798       Cardinale 2006 Cabernet Sauvignon (Napa Valley)
# 58352            Château Léoville Barton 2010  Saint-Julien
# 89728     Louis Roederer 2008 Cristal Vintage Brut  (Cha...
# 89729     Salon 2006 Le Mesnil Blanc de Blancs Brut Char...
# 111753             Château Lafite Rothschild 2010  Pauillac
# 111754    Casanova di Neri 2007 Cerretalto  (Brunello di...
# 111755             Château Cheval Blanc 2010  Saint-Émilion
# 111756        Château Léoville Las Cases 2010  Saint-Julien
# 113929    Charles Smith 2006 Royal City Syrah (Columbia ...
# 114972        Quinta do Noval 2011 Nacional Vintage  (Port)
# ...

# %%
df.loc[df['points']==100]['title'].count()
len(df.loc[df['points']==100])
# Out:
# 19

# %% [markdown]
# What is the name of the most expensive wine?

# %%
df['price'].max()
# Out:
# np.float64(3300.0)

# %%
df[df['price']==df['price'].max()]['name'].squeeze()
# Out:
# 'Glamorosa Sensible'

# %% [markdown]
# calculate a new column where you show the ratings in a scale from 0 to 5. floats are allowed

# %%
df['rating']=df['points']/20

# %%
df['rating']
# Out:
# 0         4.35
# 1         4.35
# 2         4.35
# 3         4.35
# 4         4.35
#           ...
# 129966    4.50
# 129967    4.50
# 129968    4.50
# 129969    4.50
# 129970    4.50
# Name: rating, Length: 129971, dtype: float64

# %% [markdown]
# Create a price histogram for wines that cost less than 100

# %%
df[df['price']<100]['price'].hist()
# Out:
# <bound method hist_series of 1         15.0
# 2         14.0
# 3         13.0
# 4         65.0
# 5         15.0
#           ...
# 129966    28.0
# 129967    75.0
# 129968    30.0
# 129969    32.0
# 129970    21.0
# Name: price, Length: 117024, dtype: float64>

# %% [markdown]
# Plot price horizontally against points vertically.Do you think ratings increase by price

# %%
df.plot(x='price',y='point')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.plot(x='price',y='point')
#
# File ~\PycharmProjects\WeatherAPI-6\.venv\Lib\site-packages\pandas\plotting\_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File ~\PycharmProjects\WeatherAPI-6\.venv\Lib\site-packages\pandas\plotting\_core.py:2253, in _get_plot_backend(backend)
#    2250 if backend_str in _backends:
#    2251     return _backends[backend_str]
# -> 2253 module = _load_backend(backend_str)
#    2254 _backends[backend_str] = module
#    2255 return module
# ...
